# %% [markdown]
# <a href="https://colab.research.google.com/github/dedewahyudii/Kondisi-if/blob/main/Jarak.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
Jarak = 12

if Jarak > 10:
   print("Jarak jauh")
elif Jarak < 5:
   print("Jarak Dekat")
else:
   print("Jarak Sedang")
# Out:
# Jarak jauh
